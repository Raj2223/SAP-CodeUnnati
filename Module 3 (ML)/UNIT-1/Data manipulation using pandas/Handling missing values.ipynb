# %%
import pandas as pd
import numpy as np

# %%
dict = {'First score': [100,90,np.nan,95],
        'Second score':[30,45,56,np.nan],
        'Third score':[np.nan,40,80,98]}

# creating the dataframe from list
df = pd.DataFrame(dict)

# using isnull() function:
df.isnull()
# Out:
#    First score  Second score  Third score
# 0        False         False         True
# 1        False         False        False
# 2         True         False        False
# 3        False          True        False

# %%
# reading the given file:
df = pd.read_csv(r"ds.csv")
df.head()
# Out:
#    Emp ID Name Prefix First Name Middle Initial Last Name Gender  \
# 0  677509        Drs.       Lois              H    Walker      F
# 1  940761         Ms.     Brenda              S  Robinson    NaN
# 2  428945         Dr.        Joe              W  Robinson      M
# 3  408351        Drs.      Diane              I     Evans      F
# 4  193819         Mr.   Benjamin              R   Russell      M
#
#                          E Mail     Father's Name       Mother's Name  \
# 0       lois.walker@hotmail.com     Donald Walker        Helen Walker
# 1     brenda.robinson@gmail.com  Raymond Robinson       Judy Robinson
# 2        joe.robinson@gmail.com    Scott Robinson  Stephanie Robinson
# 3         diane.evans@yahoo.com       Jason Evans      Michelle Evans
# 4  benjamin.russell@charter.net   Gregory Russell   Elizabeth Russell
#
#   Mother's Maiden Name  Salary
# 0                Lewis  168251
# 1                Perry   51063
# 2               Taylor   50155
# ...

# %%
df.isnull()
# Out:
#     Emp ID  Name Prefix  First Name  Middle Initial  Last Name  Gender  \
# 0    False        False       False           False      False   False
# 1    False        False       False           False      False    True
# 2    False        False       False           False      False   False
# 3    False        False       False           False      False   False
# 4    False        False       False           False      False   False
# ..     ...          ...         ...             ...        ...     ...
# 95   False        False       False           False      False   False
# 96   False        False       False           False      False   False
# 97   False        False       False           False      False   False
# 98   False        False       False           False      False   False
# 99   False        False       False           False      False   False
#
#     E Mail  Father's Name  Mother's Name  Mother's Maiden Name  Salary
# ...

# %%
pd.set_option('display.max_rows', None)

# %%
df.isnull()
# Out:
#     Emp ID  Name Prefix  First Name  Middle Initial  Last Name  Gender  \
# 0    False        False       False           False      False   False
# 1    False        False       False           False      False    True
# 2    False        False       False           False      False   False
# 3    False        False       False           False      False   False
# 4    False        False       False           False      False   False
# 5    False        False       False           False      False   False
# 6    False        False       False           False      False   False
# 7    False        False       False           False      False   False
# 8    False        False       False           False      False   False
# 9    False        False       False           False      False   False
# 10   False        False       False           False      False   False
# 11   False        False       False           False      False   False
# ...

# %%
Emp_ID = pd.value_counts(df["Emp ID"].isnull())
Emp_ID
# Out:
# False    100
# Name: Emp ID, dtype: int64

# %%
Name_Prefix = pd.value_counts(df["Name Prefix"].isnull())
Name_Prefix
# Out:
# False    100
# Name: Name Prefix, dtype: int64

# %%
gender = pd.value_counts(df["Gender"].isnull())
gender
# Out:
# False    99
# True      1
# Name: Gender, dtype: int64

# %% [markdown]
# # Finding the missing values:

# %%
dict = {'First score': [100,90,np.nan,95],
        'Second score':[30,45,56,np.nan],
        'Third score':[65,40,80,98]}

# creating the dataframe from list
df = pd.DataFrame(dict)

df
# Out:
#    First score  Second score  Third score
# 0        100.0          30.0           65
# 1         90.0          45.0           40
# 2          NaN          56.0           80
# 3         95.0           NaN           98

# %%
df = df.dropna(axis = 1)
df
# Out:
#    Third score
# 0           65
# 1           40
# 2           80
# 3           98

# %% [markdown]
# # drop the columns from the csv if containing nan:

# %%
df = pd.read_csv(r"ds.csv")
df = df.dropna(axis = 1)
df
# Out:
#     Emp ID Name Prefix   First Name Middle Initial   Last Name  \
# 0   677509        Drs.         Lois              H      Walker
# 1   940761         Ms.       Brenda              S    Robinson
# 2   428945         Dr.          Joe              W    Robinson
# 3   408351        Drs.        Diane              I       Evans
# 4   193819         Mr.     Benjamin              R     Russell
# 5   499687         Mr.      Patrick              F      Bailey
# 6   539712         Ms.        Nancy              T       Baker
# 7   380086        Mrs.        Carol              V      Murphy
# 8   477616        Hon.      Frances              B       Young
# 9   162402        Hon.        Diana              T    Peterson
# 10  231469         Mr.        Ralph              L      Flores
# 11  153989       Prof.         Jack              C   Alexander
# 12  386158        Mrs.      Melissa              Q        King
# 13  301576        Hon.        Wayne              G      Watson
# ...

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df = pd.read_csv(r"emp.csv")
print(df.isnull().sum().sum()) # ckeking the null values present or not
# Out:
# 322
